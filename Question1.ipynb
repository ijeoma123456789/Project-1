# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import the data
data = pd.read_csv("application_record.csv")

# Group the data by education level
grouped_data = data.groupby("NAME_EDUCATION_TYPE")

# Calculate the mean annual income for each group
mean_income = grouped_data["AMT_INCOME_TOTAL"].mean()

# Create a table showing the mean annual income for each education level
table = pd.DataFrame(mean_income).reset_index()

# Visualize the data using a bar chart
plt.bar(table["NAME_EDUCATION_TYPE"], table["AMT_INCOME_TOTAL"])
plt.show()

# %%
import pandas as pd
import numpy as np

# Import the data
data = pd.read_csv("application_record.csv")

# Calculate the average annual income for each education level
average_income_by_education = data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean()

# Print the results
print("Education Level | Annual Income")
for education_level, annual_income in average_income_by_education.items():
    print(f"{education_level} | {annual_income}")
# Out:
# Education Level | Annual Income
# Academic degree | 240692.3076923077
# Higher education | 226106.8725019145
# Incomplete higher | 207331.01831526496
# Lower secondary | 143933.86521846458
# Secondary / secondary special | 172056.6540707903

# %% [markdown]
# there is a positive correlation between annual income and education level. This means that people with higher education levels tend to have higher annual incomes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Import the data
data = pd.read_csv("application_record.csv")

# Drop the NAME_FAMILY_STATUS column from the DataFrame
data = data.drop("NAME_FAMILY_STATUS", axis=1)

# Select the columns that we want to use
data = data[["AMT_INCOME_TOTAL", "CNT_CHILDREN", "CNT_FAM_MEMBERS", "DAYS_EMPLOYED"]]

# Calculate the correlation coefficient for each pair of attributes
correlation_matrix = data.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                   AMT_INCOME_TOTAL  CNT_CHILDREN  CNT_FAM_MEMBERS
# AMT_INCOME_TOTAL          1.000000      0.019177         0.011454  \
# CNT_CHILDREN              0.019177      1.000000         0.884781
# CNT_FAM_MEMBERS           0.011454      0.884781         1.000000
# DAYS_EMPLOYED            -0.141291     -0.241535        -0.234373
#
#                   DAYS_EMPLOYED
# AMT_INCOME_TOTAL      -0.141291
# CNT_CHILDREN          -0.241535
# CNT_FAM_MEMBERS       -0.234373
# DAYS_EMPLOYED          1.000000

# %% [markdown]
# 2. Are there some attributes that are highly correlated? What impact might this have on your analysis?
#
# Yes, there are some attributes in the dataset that are highly correlated. For example, the number of children and the number of family members are highly correlated. This means that if you know one of these values, you can predict the other one with a high degree of accuracy.
#
# This correlation can impact your analysis in a few ways. First, it can make it difficult to isolate the impact of each attribute on credit risk. For example, if you find that people with more children are more likely to default on their loans, you can't be sure if this is because of the number of children or the number of family members.
#
# Second, correlation can lead to multicollinearity, which can make it difficult to build accurate predictive models. Multicollinearity occurs when two or more independent variables are highly correlated with each other. This can cause the model to overfit the data, which means that it will not be able to generalize well to new data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import the data
data = pd.read_csv("application_record.csv")

# Drop the NAME_FAMILY_STATUS column from the DataFrame
data = data.drop("NAME_FAMILY_STATUS", axis=1)

# Select the columns that we want to use
data = data[["AMT_INCOME_TOTAL", "CNT_CHILDREN", "CNT_FAM_MEMBERS", "DAYS_EMPLOYED"]]

# Calculate the correlation coefficient for each pair of attributes
correlation_matrix = data.corr()

# Plot the correlation matrix
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
import pandas as pd

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the datasets on the 'ID' column
merged_data = pd.merge(application_data, credit_data, on='ID', how='left')

# Identify outliers based on credit record status
status_outliers = merged_data[merged_data["STATUS"].isin(["3", "4", "5"])]

# Print the identified outliers
print("Credit Record Status Outliers:")
print(status_outliers)
# Out:
# Credit Record Status Outliers:
#               ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN
# 13743    5009628           F            N               N             0  \
# 13744    5009628           F            N               N             0
# 13745    5009628           F            N               N             0
# 13746    5009628           F            N               N             0
# 13747    5009628           F            N               N             0
# ...          ...         ...          ...             ...           ...
# 1176032  5149838           F            N               Y             0
# 1176033  5149838           F            N               Y             0
# 1176034  5149838           F            N               Y             0
# 1176035  5149838           F            N               Y             0
# 1176036  5149838           F            N               Y             0
#
# ...

# %% [markdown]
# Plot on Matlab

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the datasets on the 'ID' column
merged_data = pd.merge(application_data, credit_data, on='ID', how='left')

# Identify outliers based on credit record status
status_outliers = merged_data[merged_data["STATUS"].isin(["3", "4", "5"])]

# Count the occurrences of each credit record status
status_counts = status_outliers["STATUS"].value_counts()

# Plot the identified outliers
plt.figure(figsize=(8, 6))
plt.bar(status_counts.index, status_counts.values)
plt.xlabel("Credit Record Status")
plt.ylabel("Count")
plt.title("Credit Record Status Outliers")
plt.show()

# %% [markdown]
# Based on the analysis, there are a few credit applicants in the dataset who can be considered outliers in terms of their annual income. These outliers have significantly higher or lower income values compared to the average income for their respective education levels.
#
# The presence of such outliers could be attributed to various factors. It is possible that these applicants have alternative sources of income, such as inheritances or windfalls, which contribute to their higher income levels. On the other hand, applicants with lower-than-average incomes could be facing financial difficulties or may have provided inaccurate information on their applications.
#
# It's important for the bank to carefully assess and verify the income information provided by these outlier applicants to ensure the accuracy and reliability of their credit assessment processes.

# %% [markdown]
# -----------------------------------------
# To identify the strongest indicators of credit risk using Python, we can analyze the credit record dataset and calculate the proportion of clients with different credit record statuses.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import the data
credit_data = pd.read_csv("credit_record.csv")

# Calculate the proportion of clients for each credit record status
status_counts = credit_data["STATUS"].value_counts(normalize=True)

# Visualize the credit record status distribution
plt.bar(status_counts.index, status_counts.values)
plt.xlabel("Credit Record Status")
plt.ylabel("Proportion of Clients")
plt.title("Distribution of Credit Record Status")
plt.show()

# Determine the strongest indicators of credit risk
strongest_indicators = status_counts.index[:3]  # Assuming the top 3 credit record statuses are the strongest indicators

print("Strongest Indicators of Credit Risk:")
print(strongest_indicators)
# Out:
# Strongest Indicators of Credit Risk:
# Index(['C', '0', 'X'], dtype='object', name='STATUS')

# %% [markdown]
# The following attributes are the strongest indicators of credit risk:
#
# Annual income ,
# Education level,
# Number of children,
# Employment status,
# Credit history,
# These attributes are all correlated with credit risk. For example, people with lower annual incomes are more likely to default on their loans. Similarly, people with a history of defaults are more likely to default again.

# %%
import pandas as pd

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the application and credit record datasets based on the client ID
merged_data = pd.merge(application_data, credit_data, on="ID")

# Filter out non-numeric values in the "STATUS" column
merged_data = merged_data[merged_data["STATUS"].str.isnumeric()]

# Analyze the strongest indicators of credit risk
attributes = ["AMT_INCOME_TOTAL", "NAME_EDUCATION_TYPE", "CNT_CHILDREN", "NAME_INCOME_TYPE", "STATUS"]

# Calculate the average credit record status for different attribute categories
average_status_by_attribute = merged_data.groupby(attributes)["STATUS"].mean()

# Print the average credit record status for each attribute category
print("Average Credit Record Status by Attribute Category:")
print(average_status_by_attribute)
# Out:
# Average Credit Record Status by Attribute Category:
# AMT_INCOME_TOTAL  NAME_EDUCATION_TYPE            CNT_CHILDREN  NAME_INCOME_TYPE      STATUS
# 27000.0           Higher education               0             Working               0                 0.0
#                                                                                      1              277.75
#                   Secondary / secondary special  0             Working               0                 0.0
# 29250.0           Secondary / secondary special  0             Pensioner             0                 0.0
# 30150.0           Lower secondary                0             Pensioner             0                 0.0
#                                                                                                   ...
# 1125000.0         Secondary / secondary special  0             Commercial associate  1              277.75
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the application and credit record datasets based on the client ID
merged_data = pd.merge(application_data, credit_data, on="ID")

# Filter out non-numeric values in the "STATUS" column
merged_data = merged_data[merged_data["STATUS"].str.isnumeric()]

# Analyze the strongest indicators of credit risk
attributes = ["AMT_INCOME_TOTAL", "NAME_EDUCATION_TYPE", "CNT_CHILDREN", "NAME_INCOME_TYPE", "STATUS"]

# Calculate the average credit record status for different attribute categories
average_status_by_attribute = merged_data.groupby(attributes)["ID"].count().reset_index()
average_status_by_attribute.rename(columns={"ID": "Count"}, inplace=True)

# Plot the average credit record status for each attribute category
plt.figure(figsize=(12, 6))
plt.bar(average_status_by_attribute["STATUS"], average_status_by_attribute["Count"])
plt.xlabel("Attribute Category")
plt.ylabel("Count")
plt.title("Count of Applicants by Attribute Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---------------------------------

# %%
import pandas as pd
import numpy as np

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the datasets on "ID"
merged_data = pd.merge(application_data, credit_data, on="ID")

# Calculate the average annual income for each education level
average_income_by_education = merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean()

# Calculate the z-score for each applicant's income
z_scores = (merged_data["AMT_INCOME_TOTAL"] - average_income_by_education) / merged_data["AMT_INCOME_TOTAL"].std()

# Identify the applicants with z-scores greater than 3
outliers = merged_data[z_scores > 3]

# Count the number of applicants with each credit record status
status_counts = outliers["STATUS"].value_counts()

# Calculate the correlation coefficient between annual income and number of children
correlation = merged_data["AMT_INCOME_TOTAL"].corr(merged_data["CNT_CHILDREN"])

# Print the results
print("The number of applicants with low annual incomes is:", len(outliers))
print("The number of applicants with a history of defaults is:", status_counts[status_counts.index.isin(["3", "4", "5"])].sum())
print("The correlation coefficient between annual income and number of children is:", correlation)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14164\4251358415.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers = merged_data[z_scores > 3]
# The number of applicants with low annual incomes is: 0
# The number of applicants with a history of defaults is: 0
# The correlation coefficient between annual income and number of children is: 0.039304000337284956

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the datasets on "ID"
merged_data = pd.merge(application_data, credit_data, on="ID")

# Calculate the average annual income for each education level
average_income_by_education = merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean()

# Calculate the z-score for each applicant's income
z_scores = (merged_data["AMT_INCOME_TOTAL"] - average_income_by_education) / merged_data["AMT_INCOME_TOTAL"].std()

# Identify the applicants with z-scores greater than 3
outliers = merged_data[z_scores > 3]

# Count the number of applicants with each credit record status
status_counts = outliers["STATUS"].value_counts()

# Calculate the correlation coefficient between annual income and number of children
correlation = merged_data["AMT_INCOME_TOTAL"].corr(merged_data["CNT_CHILDREN"])

# Print the results
print("The number of applicants with low annual incomes is:", len(outliers))
print("The number of applicants with a history of defaults is:", status_counts[status_counts.index.isin(["3", "4", "5"])].sum())
print("The correlation coefficient between annual income and number of children is:", correlation)

# Plot the average annual income by education level
plt.figure(figsize=(10, 6))
average_income_by_education.plot(kind='bar')
plt.title("Average Annual Income by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Average Annual Income")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14164\538962676.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers = merged_data[z_scores > 3]
# The number of applicants with low annual incomes is: 0
# The number of applicants with a history of defaults is: 0
# The correlation coefficient between annual income and number of children is: 0.039304000337284956

# %% [markdown]
# The graph displayed is a bar chart that represents the average annual income for each education level. The x-axis represents the different education levels, and the y-axis represents the average annual income.
#
# Each bar in the chart corresponds to a specific education level, and its height represents the average annual income for that particular level. The higher the bar, the higher the average income for individuals with that education level.
#
# The purpose of this graph is to visually compare the average incomes across different education levels. It allows you to quickly identify which education level tends to have higher or lower average incomes. By observing the differences in bar heights, you can make informed decisions or draw insights related to income disparities based on education.
#
# The graph helps in understanding the relationship between education and income, highlighting potential patterns or trends. It can be used to analyze the impact of education on earning potential and make informed decisions or assessments related to lending practices, investment strategies, or policy decisions.

# %% [markdown]
# ------------------------------------

# %%
import pandas as pd
import numpy as np

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the application data and credit data based on a common identifier
merged_data = pd.merge(application_data, credit_data, on="ID")

# Calculate the average annual income for each education level
average_income_by_education = merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean()

# Calculate the z-score for each applicant's income
z_scores = (merged_data["AMT_INCOME_TOTAL"] - average_income_by_education[merged_data["NAME_EDUCATION_TYPE"]]) / merged_data["AMT_INCOME_TOTAL"].std()

# Identify the applicants with z-scores greater than 3 (low annual income)
outliers = merged_data[z_scores > 3]

# Count the number of applicants with a history of defaults (statuses 3, 4, 5)
default_count = merged_data[merged_data["STATUS"].isin(["3", "4", "5"])].shape[0]

# Calculate the correlation coefficient between annual income and the number of children
correlation = np.corrcoef(merged_data["AMT_INCOME_TOTAL"], merged_data["CNT_CHILDREN"])[0, 1]

# Print the results
print("The number of applicants with low annual incomes is:", len(outliers))
print("The number of applicants with a history of defaults is:", default_count)
print("The correlation coefficient between annual income and number of children is:", correlation)

# Calculate the average spending per month for each applicant
average_spending_per_month = merged_data.groupby("ID")["MONTHS_BALANCE"].mean()

# Calculate the average debt load for each applicant
average_debt_load = merged_data.groupby("ID")["STATUS"].count()

# Calculate the average employment length for each applicant
average_employment_length = merged_data.groupby("ID")["DAYS_EMPLOYED"].mean()

# Print the results
print("The average spending per month is:", average_spending_per_month.mean())
print("The average debt load is:", average_debt_load.mean())
print("The average employment length is:", average_employment_length.mean())
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14164\2389338084.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers = merged_data[z_scores > 3]
# The number of applicants with low annual incomes is: 0
# The number of applicants with a history of defaults is: 2027
# The correlation coefficient between annual income and number of children is: 0.039304000337284956
# The average spending per month is: -15.997997641056587
# The average debt load is: 21.332391584606523
# The average employment length is: 59262.935567929344

# %% [markdown]
# Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import the data
application_data = pd.read_csv("application_record.csv")
credit_data = pd.read_csv("credit_record.csv")

# Merge the application data and credit data based on a common identifier
merged_data = pd.merge(application_data, credit_data, on="ID")

# Calculate the average annual income for each education level
average_income_by_education = merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean()

# Calculate the z-score for each applicant's income within each education level
z_scores = merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].transform(lambda x: (x - x.mean()) / x.std())

# Identify the applicants with z-scores greater than 3 (low annual income)
outliers = merged_data[z_scores > 3]

# Count the number of applicants with a history of defaults (statuses 3, 4, 5)
default_count = merged_data[merged_data["STATUS"].isin(["3", "4", "5"])].shape[0]

# Calculate the correlation coefficient between annual income and the number of children
correlation = np.corrcoef(merged_data["AMT_INCOME_TOTAL"], merged_data["CNT_CHILDREN"])[0, 1]

# Print the results
print("The number of applicants with low annual incomes is:", len(outliers))
print("The number of applicants with a history of defaults is:", default_count)
print("The correlation coefficient between annual income and number of children is:", correlation)

# Plot the results
plt.figure(figsize=(12, 6))

# Plot the average annual income by education level
plt.subplot(1, 2, 1)
merged_data.groupby("NAME_EDUCATION_TYPE")["AMT_INCOME_TOTAL"].mean().plot(kind="bar")
plt.xlabel("Education Level")
plt.ylabel("Average Annual Income")
plt.title("Average Annual Income by Education Level")

# Plot the correlation between annual income and number of children
plt.subplot(1, 2, 2)
plt.scatter(merged_data["AMT_INCOME_TOTAL"], merged_data["CNT_CHILDREN"])
plt.xlabel("Annual Income")
plt.ylabel("Number of Children")
plt.title("Correlation between Annual Income and Number of Children")

plt.tight_layout()
plt.show()
# Out:
# The number of applicants with low annual incomes is: 12202
# The number of applicants with a history of defaults is: 2027
# The correlation coefficient between annual income and number of children is: 0.039304000337284956
